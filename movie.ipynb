# %% [markdown]
# 파이썬데이터분석 11주차 과제
#
# 201904236 전병준
# 201904201 김찬민

# %%
# !pip install koreanize-matplotlib
import koreanize_matplotlib
# Out:
# Requirement already satisfied: koreanize-matplotlib in c:\users\pc\anaconda3\lib\site-packages (0.1.1)
# Requirement already satisfied: matplotlib in c:\users\pc\anaconda3\lib\site-packages (from koreanize-matplotlib) (3.4.3)
# Requirement already satisfied: numpy>=1.16 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib->koreanize-matplotlib) (1.20.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib->koreanize-matplotlib) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib->koreanize-matplotlib) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib->koreanize-matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib->koreanize-matplotlib) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib->koreanize-matplotlib) (2.8.2)
# Requirement already satisfied: six in c:\users\pc\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->koreanize-matplotlib) (1.16.0)

# %%
import pandas as pd
df1= pd.read_excel('한국영화데이터.xlsx')

# %%
import pandas as pd
df2= pd.read_excel('외국영화데이터.xlsx')

# %%
import pandas as pd
df3= pd.read_excel('전체영화데이터.xlsx')

# %%
df = pd.read_csv('./영화데이터.csv',encoding='cp949')
def remove_comma(x):
    if isinstance(x, str):
        return x.replace(',', '')
    return x

df = df.applymap(remove_comma)
df
# Out:
#          년월  한국개봉편수  한국상영편수         한국매출액     한국관객수  한국점유율  국외개봉편수  국외상영편수  \
# 0   2015-01      15      82  110123050402  14019496  62.4%      67     210
# 1   2015-02      13      87   63402259578   8048675  48.3%      64     209
# 2   2015-03      17      99   30469065119   3899544  34.4%      59     235
# 3   2015-04      18     100   24782124375   3255669  25.6%      74     248
# 4   2015-05      16     103   44274804858   5560234  31.5%      70     241
# ..      ...     ...     ...           ...       ...    ...     ...     ...
# 95  2022-12      42     191   53028283932   5428075  38.3%      90     264
# 96  2023-01      43     122   44930621839   4464796  39.7%      81     199
# 97  2023-02      32      95   13445424160   1271914  19.8%      72     203
# 98  2023-03      52     118   21465852011   1874516  25.1%      93     233
# 99  2023-04      57     153   16895809306   1731029  24.8%      62     220
#
#            국외매출액     국외관객수  국외점유율  전체개봉편수  전체상영편수         전체매출액     전체관객수
# 0    66172275249   8464595  37.6%      82     292  176295325651  22484091
# 1    68118614692   8617498  51.7%      77     296  131520874270  16666173
# 2    59199074299   7423563  65.6%      76     334   89668139418  11323107
# 3    78418983748   9465970  74.4%      92     348  103201108123  12721639
# 4   100000237495  12110506  68.5%      86     344  144275042353  17670740
# ..           ...       ...    ...     ...     ...           ...       ...
# 95  104617508194   8743696  61.7%     132     455  157645792126  14171771
# 96   79142587534   6785561  60.3%     124     321  124073209373  11250357
# 97   55605073815   5149381  80.2%     104     298   69050497975   6421295
# 98   58556782604   5601689  74.9%     145     351   80022634615   7476205
# 99   53792721270   5241391  75.2%     119     373   70688530576   6972420
#
# [100 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년월      100 non-null    object
#  1   한국개봉편수  100 non-null    int64
#  2   한국상영편수  100 non-null    int64
#  3   한국매출액   100 non-null    int64
#  4   한국관객수   100 non-null    object
#  5   한국점유율   100 non-null    object
#  6   국외개봉편수  100 non-null    int64
#  7   국외상영편수  100 non-null    int64
#  8   국외매출액   100 non-null    object
#  9   국외관객수   100 non-null    object
#  10  국외점유율   100 non-null    object
#  11  전체개봉편수  100 non-null    int64
#  12  전체상영편수  100 non-null    int64
#  13  전체매출액   100 non-null    object
#  14  전체관객수   100 non-null    object
# dtypes: int64(7), object(8)
# memory usage: 11.8+ KB

# %%
df.describe()
# Out:
#            한국개봉편수      한국상영편수         한국매출액      국외개봉편수      국외상영편수  \
# count  100.000000  100.000000  1.000000e+02  100.000000  100.000000
# mean    50.020000  150.030000  5.845290e+10   93.750000  274.100000
# std     19.933212   41.707363  4.313516e+10   16.519578   41.388404
# min     13.000000   77.000000  1.120063e+09   59.000000  186.000000
# 25%     33.000000  126.000000  2.522767e+10   81.750000  243.000000
# 50%     51.000000  144.500000  5.182767e+10   93.000000  269.500000
# 75%     65.000000  170.250000  8.497930e+10  104.000000  299.250000
# max     97.000000  291.000000  1.861706e+11  139.000000  391.000000
#
#            전체개봉편수      전체상영편수
# count  100.000000  100.000000
# mean   143.770000  424.130000
# std     27.471879   72.783012
# min     76.000000  276.000000
# 25%    126.750000  374.500000
# 50%    147.000000  426.500000
# 75%    159.250000  459.250000
# max    215.000000  651.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df['년월'] = pd.to_datetime(df['년월'])

# %%
df.set_index('년월', inplace=True)

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['한국매출액'])
plt.xlabel('년월')
plt.ylabel('한국매출액')
plt.title('월별 한국매출액 변화')
plt.xticks(rotation=45)
plt.show()

# %%
# 년도와 월을 분리

df = pd.read_csv('./영화데이터.csv',encoding='cp949')
def remove_comma(x):
    if isinstance(x, str):
        return x.replace(',', '')
    return x

df = df.applymap(remove_comma)

df['년도'] = df['년월'].str.split('-').str[0]
df['월'] = df['년월'].str.split('-').str[1]

# 월별 한국매출액 변화 시각화
colors = ['red', 'green', 'blue', 'orange', 'purple', 'black', 'pink', 'brown', 'gray']
fig, ax = plt.subplots()

for i, year in enumerate(df['년도'].unique()):
    year_df = df[df['년도'] == year]
    ax.plot(year_df['월'], year_df['한국매출액'], color=colors[i], label=year)

ax.set_xlabel('월')
ax.set_ylabel('한국매출액')
ax.set_title('년한국매출액 변화')
ax.legend()

plt.show()
